# %%
import os
import numpy as np
import math
from time import time
from PIL import Image
import cv2
from matplotlib import pyplot as plt
import csv
import random

# %%
with open('/Users/vladkorsikov/research/dataset_main/5_all_vectors/pituitary/pituitary_horizontal_vector.csv', newline='') as file:
    glioma_hor_vectors_0 = [row for row in csv.reader(file)]

# %%
glioma_hor_vectors = []

for vector in glioma_hor_vectors_0:
    vector_add = []
    for bit in vector:
        bat = int(bit)
        vector_add.append(bat)
    glioma_hor_vectors.append(vector_add)

#Проверяем на случайном изображении
first_reference_number = 8
print(f'Первое эталонное изображение: glioma{first_reference_number+1}.png с номером вектора: {first_reference_number}')
# Out:
# Первое эталонное изображение: glioma9.png с номером вектора: 8

# %%
#зададим функцию поиска скалярного произведения
first = glioma_hor_vectors[18]
second = glioma_hor_vectors[19]
#print(first)
#print(hope_2)

#def optimization_vector_for_scalar_product (vector):
#    not_null_list = []
#    for number in vector:
#        if number > 0:
#            not_null_list.append(number)
#    return not_null_list



#optim_1 = optimization_vector_for_scalar_product(first)
#optim_2 = optimization_vector_for_scalar_product(second)

#print(len(optim_1))
#print(len(optim_2))


def scalar_product_vector_column_and_row(target_vector, list_vector):
    scal_product = 0
    for num_v, num_l in zip(target_vector, list_vector):
        num_v = int(num_v)
        num_l = int(num_l)
        increment=num_v*num_l
        scal_product +=increment
    return scal_product
        

scalar = scalar_product_vector_column_and_row(first, second)

print(scalar)

# теперь ищем норму выражения
def vector_norm(vector):
    norm_sq = 0
    for element in vector:
        element_sq = element**2
        norm_sq += element_sq
    norm = math.sqrt(norm_sq)
    norm = int(norm)
    return norm

norm_vec_1 = vector_norm(first)
norm_vec_2 = vector_norm(second)

def cos_criterea(scalar_product, norm_vec_1, norm_vec_2):
    norm_vec = norm_vec_1*norm_vec_2
    criterea = scalar_product/norm_vec
    return criterea



print(norm_vec_1)
print(norm_vec_2)
print(norm_vec_1*norm_vec_2)

final = cos_criterea(scalar, norm_vec_1, norm_vec_2)
print(final)

#scalar = scalar_product(example_image, example_image_2)
#print(scalar)
# Out:
# 272424709
# 17562
# 16444
# 288789528
# 0.9433330595006894

# %%
trio_list = []
for analizing_number in range(len(glioma_hor_vectors)):
    first_reference = glioma_hor_vectors[analizing_number]
    first_reference_norm = vector_norm(first_reference)
    cos_criterea_list=[]
    for vector in glioma_hor_vectors:
        scalar_prod = scalar_product_vector_column_and_row(first_reference, vector)
        vector_normal = vector_norm(first_reference)
        criterea = cos_criterea(scalar_prod, first_reference_norm, vector_normal)
        cos_criterea_list.append(criterea)
    best_criteria = 999999999999
    criteria_number = -1
    current_best_number = 0
    for criteria in cos_criterea_list:
        criteria_number +=1
        if criteria < best_criteria:
            best_criteria = criteria
            current_best_number = criteria_number
    trio = [analizing_number, current_best_number, best_criteria]
    trio_list.append(trio)

print(trio_list)
# Out:
# [[0, 26, 0.3608400642602648], [1, 26, 0.3784528114877756], [2, 26, 0.39266814869183136], [3, 49, 0.4307464602584388], [4, 49, 0.4504512787555804], [5, 26, 0.48517074182306724], [6, 26, 0.4051594179124493], [7, 26, 0.37954112640854226], [8, 49, 0.39794743114769854], [9, 49, 0.4068073842322436], [10, 26, 0.5058154065394974], [11, 26, 0.47635681475703195], [12, 26, 0.5337009834102223], [13, 49, 0.5537009311174698], [14, 49, 0.5233765900794346], [15, 26, 0.51736997692549], [16, 26, 0.6096715535722088], [17, 49, 0.6026717879161908], [18, 49, 0.36864223766045795], [19, 49, 0.3962991960330221], [20, 49, 0.40212637256847267], [21, 26, 0.46266676955326325], [22, 26, 0.47579632723716136], [23, 49, 0.39303590788195303], [24, 49, 0.49369832356852517], [25, 49, 0.5401514777690328], [26, 49, 0.6012678754090874], [27, 49, 0.5863987583956707], [28, 26, 0.476198456104136], [29, 26, 0.454767952051133], [30, 26, 0.4987269595496822], [31, 26, 0.4595069050230966], [32, 49, 0.4464514742365529], [33, 49, 0.5520323267618097], [34, 49, 0.5502093608695725], [35, 49, 0.5571050558818934], [36, 49, 0.48781366283914146], [37, 49, 0.47792442208364827], [38, 49, 0.4682404334272269], [39, 49, 0.47028197562626334], [40, 49, 0.36875353925100957], [41, 49, 0.4399204202924586], [42, 26, 0.4843275942576207], [43, 26, 0.4987848419535236], [44, 26, 0.46023375241460307], [45, 26, 0.4724463096197409], [46, 26, 0.48369394448786296], [47, 26, 0.6660596117315079], [48, 26, 0.723510113862791], [49, 26, 0.802376526711404], [50, 26, 0.59035428110945], [51, 49, 0.4023794587382271], [52, 49, 0.42022638933016515], [53, 49, 0.49925812730515445], [54, 26, 0.4264200469713026], [55, 26, 0.4193059979930044], [56, 26, 0.43582756388937394], [57, 26, 0.45567962597041994], [58, 26, 0.4224057487496933], [59, 49, 0.502621728164123], [60, 49, 0.44929605496088365], [61, 49, 0.48910942734555496], [62, 49, 0.47429026232349564], [63, 49, 0.467871089050451], [64, 49, 0.5472648920585366], [65, 49, 0.45801951911777206], [66, 49, 0.45785015676082985], [67, 49, 0.5107628245256668], [68, 49, 0.5528250489890826], [69, 49, 0.569943330702628], [70, 49, 0.5000737680315303], [71, 49, 0.5340682344672375], [72, 26, 0.4142668095138295], [73, 49, 0.4763693026178893], [74, 49, 0.47379251123446414], [75, 26, 0.46924844642565783], [76, 49, 0.5073611124857023], [77, 49, 0.40871343885364186], [78, 49, 0.38142644017717336], [79, 49, 0.38257698131328377], [80, 49, 0.41041590425953206], [81, 49, 0.4334397017523041], [82, 49, 0.4356184612369722], [83, 49, 0.49017299564177474], [84, 26, 0.48814672949179005], [85, 26, 0.49169093297104094], [86, 49, 0.46836542920868546], [87, 49, 0.5140099654125825], [88, 49, 0.5104947014475698], [89, 49, 0.5354542242044751], [90, 49, 0.5280161204324009], [91, 26, 0.4383704940312213], [92, 49, 0.47976694204934245], [93, 49, 0.561950079296821], [94, 49, 0.6066673545133874], [95, 49, 0.5120850096108568], [96, 49, 0.5131177679062577], [97, 49, 0.5075670610352075], [98, 26, 0.5904310764367527], [99, 26, 0.5061901800549999]]

# %%
trio_best_criteria = 999999999999
trio_criteria_number = -1
trio_current_best_number = []

for tr in trio_list:
    trio_criteria_number +=1
    if tr[2]<trio_best_criteria:
        trio_best_criteria = tr[2]
        trio_current_best_number = tr

print(trio_current_best_number)
# Out:
# [0, 26, 0.3608400642602648]

# %%
#Сохраним основания двух первичных классов и их косинусный критерий

trio_current_best_number_2 = []
count_tt = 0
for c in trio_current_best_number:
    part_tt  = []
    count_tt +=1
    part_tt.append(count_tt)
    part_tt.append(c)
    trio_current_best_number_2.append(part_tt)
    
print(trio_current_best_number_2)  

with open('/Users/vladkorsikov/research/dataset_main/5_all_vectors/pituitary/pituitary_class_first_and_second_core_vectors.csv', 'w', newline='') as f:
    csv.writer(f).writerows(trio_current_best_number_2)
# Out:
# [[1, 0], [2, 26], [3, 0.3608400642602648]]

# %%
#print(f'Второе эталонное изображение: glioma{current_best_number+1}.png с номером вектора: {current_best_number}')

# %%
# Пример пары эталонных изображений - 4 и 37, в следующем скрипте будем работать с ними
